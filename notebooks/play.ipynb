# %%
from google import genai
from google.genai import types
import base64
import os

def generate():
  client = genai.Client(
      vertexai=True,
      api_key="AQ.Ab8RN6K_mq8HFCRCxG-ffna93mhI_YutRJcmH8EgWvIfKyr9fQ",
  )

  image1 = types.Part.from_uri(
      file_uri="gs://cloud-samples-data/generative-ai/image/homework.png",
      mime_type="image/png",
  )

  model = "gemini-3-flash-preview"
  contents = [
    types.Content(
      role="user",
      parts=[
        image1,
        types.Part.from_text(text="""Answer the question in the image with step by step solution.""")
      ]
    )
  ]

  generate_content_config = types.GenerateContentConfig(
    temperature = 1,
    top_p = 0.95,
    seed = 0,
    max_output_tokens = 65535,
    safety_settings = [types.SafetySetting(
      category="HARM_CATEGORY_HATE_SPEECH",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_DANGEROUS_CONTENT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_SEXUALLY_EXPLICIT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_HARASSMENT",
      threshold="OFF"
    )],
    thinking_config=types.ThinkingConfig(
      thinking_level="HIGH",
    ),
  )

  for chunk in client.models.generate_content_stream(
    model = model,
    contents = contents,
    config = generate_content_config,
    ):
    print(chunk.text, end="")

generate()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[3], line 58
#      51   for chunk in client.models.generate_content_stream(
#      52     model = model,
#      53     contents = contents,
#      54     config = generate_content_config,
#      55     ):
#      56     print(chunk.text, end="")
# ---> 58 generate()
#
# Cell In[3], line 51, in generate()
#      18 contents = [
#      19   types.Content(
#      20     role="user",
#    (...)
#      25   )
#      26 ]
#      28 generate_content_config = types.GenerateContentConfig(
#      29   temperature = 1,
#      30   top_p = 0.95,
#    (...)
#      48   ),
#      49 )
# ---> 51 for chunk in client.models.generate_content_stream(
#      52   model = model,
#      53   contents = contents,
#      54   config = generate_content_config,
#      55   ):
#      56   print(chunk.text, end="")
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/google/genai/models.py:5651, in Models.generate_content_stream(self, model, contents, config)
#    5645 function_map = _extra_utils.get_function_map(parsed_config)
#    5647 if i == 1:
#    5648   # First request gets a function call.
#    5649   # Then get function response parts.
#    5650   # Yield chunks only if there's no function response parts.
# -> 5651   for chunk in response:
#    5652     if not function_map:
#    5653       contents = _extra_utils.append_chunk_contents(contents, chunk)  # type: ignore[assignment]
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/google/genai/models.py:4307, in Models._generate_content_stream(self, model, contents, config)
#    4299 if config is not None and getattr(
#    4300     config, 'should_return_http_response', None
#    4301 ):
#    4302   raise ValueError(
#    4303       'Accessing the raw HTTP response is not supported in streaming'
#    4304       ' methods.'
#    4305   )
# -> 4307 for response in self._api_client.request_streamed(
#    4308     'post', path, request_dict, http_options
#    4309 ):
#    4311   response_dict = {} if not response.body else json.loads(response.body)
#    4313   if self._api_client.vertexai:
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1413, in BaseApiClient.request_streamed(self, http_method, path, request_dict, http_options)
#    1402 def request_streamed(
#    1403     self,
#    1404     http_method: str,
#    (...)
#    1407     http_options: Optional[HttpOptionsOrDict] = None,
#    1408 ) -> Generator[SdkHttpResponse, None, None]:
#    1409   http_request = self._build_request(
#    1410       http_method, path, request_dict, http_options
#    1411   )
# -> 1413   session_response = self._request(http_request, http_options, stream=True)
#    1414   for chunk in session_response.segments():
#    1415     chunk_dump = json.dumps(chunk)
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1232, in BaseApiClient._request(self, http_request, http_options, stream)
#    1229     retry = tenacity.Retrying(**retry_kwargs)
#    1230     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1232 return self._retry(self._request_once, http_request, stream)
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1197, in BaseApiClient._request_once(self, http_request, stream)
#    1189   httpx_request = self._httpx_client.build_request(
#    1190       method=http_request.method,
#    1191       url=http_request.url,
#    (...)
#    1194       timeout=http_request.timeout,
#    1195   )
#    1196   response = self._httpx_client.send(httpx_request, stream=stream)
# -> 1197   errors.APIError.raise_for_response(response)
#    1198   return HttpResponse(
#    1199       response.headers, response if stream else [response.text]
#    1200   )
#    1201 else:
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/google/genai/errors.py:134, in APIError.raise_for_response(cls, response)
#     131 else:
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File ~/Desktop/hackathons/bhashabridge/.venv/lib/python3.10/site-packages/google/genai/errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     145 """Raises an appropriate APIError subclass based on the status code.
#     146
#     147 Args:
#    (...)
#     156   APIError: For other error status codes.
#     157 """
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#     161   raise ServerError(status_code, response_json, response)
#
# ClientError: 401 UNAUTHENTICATED. {'error': {'code': 401, 'message': 'API keys are not supported by this API. Expected OAuth2 access token or other authentication credentials that assert a principal. See https://cloud.google.com/docs/authentication', 'status': 'UNAUTHENTICATED', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'CREDENTIALS_MISSING', 'domain': 'googleapis.com', 'metadata': {'method': 'google.cloud.aiplatform.v1beta1.PredictionService.StreamGenerateContent', 'service': 'aiplatform.googleapis.com'}}]}}
